# %%
import sys
import os
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
import asyncio
import json
import aiohttp
from understat import Understat
from collections import namedtuple
from types import SimpleNamespace

# %%
# Get each team from that league
async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        table = await understat.get_league_table("La_Liga", "2024")

leagueTable = pd.DataFrame(table[1:], columns=table[0])
leagueTable
# Out:
#                Team   M   W   D   L   G  GA  PTS     xG   NPxG    xGA  NPxGA  \
# 0         Barcelona  32  23   4   5  88  32   73  84.04  78.84  35.12  32.89
# 1       Real Madrid  31  20   6   5  64  31   66  70.26  61.35  35.02  32.79
# 2   Atletico Madrid  32  18   9   5  53  27   63  57.48  52.28  34.28  30.56
# 3     Athletic Club  31  15  12   4  49  25   57  52.10  47.64  32.94  29.88
# 4        Villarreal  30  14   9   7  53  40   51  59.84  54.49  38.37  34.65
# 5        Real Betis  31  13   9   9  42  39   48  51.68  44.99  39.80  36.82
# 6          Mallorca  32  12   8  12  31  37   44  39.80  36.08  38.70  36.47
# 7        Celta Vigo  32  12   7  13  47  49   43  47.13  41.93  39.45  37.08
# 8     Real Sociedad  31  12   5  14  30  34   41  37.57  36.09  38.71  34.25
# 9    Rayo Vallecano  32  10  11  11  35  39   41  42.29  41.46  47.93  43.47
# 10           Getafe  32  10   9  13  31  29   39  34.79  31.08  41.73  36.53
# 11         Espanyol  31  10   8  13  34  40   38  30.54  27.56  50.08  45.62
# 12          Osasuna  31   8  14   9  36  44   38  38.17  32.97  49.97  46.26
# 13         Valencia  32   9  11  12  36  48   38  39.56  37.33  48.67  43.46
# 14          Sevilla  31   9   9  13  34  42   36  34.26  32.78  43.70  39.24
# 15           Girona  31   9   7  15  38  48   34  39.07  35.36  44.72  41.00
# 16       Las Palmas  32   8   8  16  38  52   32  33.86  31.63  64.80  58.11
# 17           Alaves  31   7   9  15  33  45   30  37.84  31.90  44.02  35.85
# 18          Leganes  32   6  11  15  29  48   29  31.37  26.17  57.39  51.45
# 19  Real Valladolid  31   4   4  23  21  73   16  27.60  24.63  63.89  60.17
#
#     NPxGD   PPDA  OPPDA   DC  ODC   xPTS
# 0   45.95   6.86  15.23  386  105  71.34
# 1   28.55  11.25  15.70  300  141  61.13
# 2   21.72  13.90  14.12  237  160  57.16
# 3   17.76  11.38  11.17  172  121  52.91
# 4   19.84  12.62  10.94  236  165  54.99
# 5    8.16  10.15  10.17  204  151  50.81
# 6   -0.39  12.30   9.27  125  192  46.24
# 7    4.85  11.41  14.30  221  155  49.71
# 8    1.83   8.09  12.12  187  151  42.56
# 9   -2.01   8.37  10.44  148  175  40.23
# 10  -5.45   9.54   6.20  115  151  39.38
# 11 -18.05  15.48   8.98  103  256  30.71
# 12 -13.28  11.48  10.32  135  223  36.02
# 13  -6.13  12.96   9.81  134  185  41.45
# 14  -6.47  11.50  11.80  129  150  35.87
# 15  -5.64  10.67  13.96  207  164  39.94
# 16 -26.48  11.76  11.15  159  240  26.16
# 17  -3.95   9.91   8.78  123  139  39.45
# 18 -25.28  12.65   8.75  116  222  28.30
# 19 -35.54  14.68  10.33   70  261  25.56

# %%
async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        team_stats = await understat.get_team_stats("Barcelona", 2024)

def flatten_stat_section(section_name, section_data):
    df = pd.DataFrame.from_dict(section_data, orient="index")
    df.reset_index(inplace=True)
    df.rename(columns={"index": section_name}, inplace=True)

    # Flatten the nested 'against' dictionary
    if 'against' in df.columns:
        against_df = pd.json_normalize(df['against'])  # Convert dict to columns
        against_df.columns = [f"against_{col}" for col in against_df.columns]  # Rename columns
        df = pd.concat([df.drop(columns=['against']), against_df], axis=1)  # Combine and remove old column

    if "stat" in df.columns:
        df = df.drop(columns=['stat'])

    return df

situation = flatten_stat_section("situation", team_stats["situation"])
timing = flatten_stat_section("timing", team_stats["timing"])
shot_zone = flatten_stat_section("shotZone", team_stats["shotZone"])
attack_speed = flatten_stat_section("attackSpeed", team_stats["attackSpeed"])

# %%
# List dataframes
df_dict = {
    "situation": situation,
    "timing": timing,
    "shot_zone": shot_zone,
    "attack_speed": attack_speed,
}

# Display one under the other
for df in df_dict:
    display(df_dict[df])
# Out:
#         situation  shots  goals         xG  against_shots  against_goals  \
# 0        OpenPlay    419     69  69.554013            196             27
# 1      FromCorner     76      7   7.062155             35              2
# 2  DirectFreekick     23      1   1.617523              7              0
# 3        SetPiece     19      5   4.575287             11              0
# 4         Penalty      7      6   5.202943              3              3
#
#    against_xG
# 0   27.258089
# 1    2.858903
# 2    0.353514
# 3    2.608172
# 4    2.229833
#   timing  shots  goals         xG  against_shots  against_goals  against_xG
# 0   1-15     70     12  12.182448             35              4    4.964253
# 1  16-30     83     17  15.545750             33              3    3.490968
# 2  31-45     83      7  11.318266             42              7    8.072534
# 3  46-60    121     19  18.323094             48              5    5.918752
# 4  61-75     80     12  13.474933             39              6    6.099062
# 5    76+    107     21  17.167431             55              7    6.762941
#           shotZone  shots  goals         xG  against_shots  against_goals  \
# 0         ownGoals      3      3   3.000000              0              0
# 1    shotOboxTotal    187     13   8.084643             67              2
# 2  shotPenaltyArea    301     56  55.898192            167             23
# 3   shotSixYardBox     53     16  21.029087             18              7
#
#    against_xG
# 0    0.000000
# 1    2.339317
# 2   26.521113
# 3    6.448080
#   attackSpeed  shots  goals         xG  against_shots  against_goals  \
# 0      Normal    330     52  50.959581            151             17
# 1    Standard    125     19  18.457908             56              5
# 2        Slow     52      9   8.739464             15              1
# 3        Fast     37      8   9.854969             30              9
#
#    against_xG
# 0   19.874912
# 1    8.050421
# 2    1.212252
# 3    6.170925

# %%
async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        results = await understat.get_team_results(
            "Barcelona",
            2024
        )
        
df = pd.DataFrame(results)
# Extract necessary info
df_cleaned = pd.DataFrame({
    'MatchID': df['id'],
    'side': df['side'],
    'HomeTeam': df['h'].apply(lambda x: eval(x)['title'] if isinstance(x, str) else x['title']),
    'AwayTeam': df['a'].apply(lambda x: eval(x)['title'] if isinstance(x, str) else x['title']),
    'HomeGoals': df['goals'].apply(lambda x: int(eval(x)['h']) if isinstance(x, str) else int(x['h'])),
    'HomexG': df['xG'].apply(lambda x: float(eval(x)['h']) if isinstance(x, str) else float(x['h'])),
    'AwayGoals': df['goals'].apply(lambda x: int(eval(x)['a']) if isinstance(x, str) else int(x['a'])),
    'AwayxG': df['xG'].apply(lambda x: float(eval(x)['a']) if isinstance(x, str) else float(x['a'])),
    'Forecast': df['forecast'],
    'Result': df['result']
})

# If 'forecast' is a string dict, you can optionally parse it too:
df_cleaned['Forecast'] = df_cleaned['Forecast'].apply(lambda x: eval(x) if isinstance(x, str) else x)

# Split forecast dictionary into separate columns
df_cleaned['Odds Win'] = df_cleaned['Forecast'].apply(lambda x: x['w']) * 100
df_cleaned['Odds Draw'] = df_cleaned['Forecast'].apply(lambda x: x['d']) * 100
df_cleaned['Odss Loss'] = df_cleaned['Forecast'].apply(lambda x: x['l']) * 100
df_cleaned = df_cleaned.drop(columns="Forecast")

# Preview
df_cleaned
# Out:
#    MatchID side         HomeTeam         AwayTeam  HomeGoals    HomexG  \
# 0    26987    a         Valencia        Barcelona          1  1.552060
# 1    26995    h        Barcelona    Athletic Club          2  2.415770
# 2    27004    a   Rayo Vallecano        Barcelona          1  0.392473
# 3    27012    h        Barcelona  Real Valladolid          7  4.940220
# 4    27028    a           Girona        Barcelona          1  1.095680
# 5    27037    a       Villarreal        Barcelona          1  2.396050
# 6    27043    h        Barcelona           Getafe          1  2.207990
# 7    27056    a          Osasuna        Barcelona          4  2.500670
# 8    27064    a           Alaves        Barcelona          0  0.794829
# 9    27074    h        Barcelona          Sevilla          5  4.085280
# 10   27085    a      Real Madrid        Barcelona          0  1.403590
# 11   27101    h        Barcelona         Espanyol          3  1.943980
# 12   27108    a    Real Sociedad        Barcelona          1  1.885180
# 13   27117    a       Celta Vigo        Barcelona          2  2.759810
# 14   27122    h        Barcelona       Las Palmas          1  2.183540
# 15   27167    a         Mallorca        Barcelona          1  0.921728
# 16   27139    a       Real Betis        Barcelona          2  2.762570
# 17   27143    h        Barcelona          Leganes          0  2.165970
# 18   27160    h        Barcelona  Atletico Madrid          1  3.374240
# 19   27177    a           Getafe        Barcelona          1  1.169210
# 20   27184    h        Barcelona         Valencia          7  4.358750
# 21   27200    h        Barcelona           Alaves          1  1.185260
# 22   27206    a          Sevilla        Barcelona          1  0.921429
# 23   27214    h        Barcelona   Rayo Vallecano          1  2.827750
# 24   27226    a       Las Palmas        Barcelona          0  0.431009
# 25   27232    h        Barcelona    Real Sociedad          4  3.636970
# 26   27252    a  Atletico Madrid        Barcelona          2  1.094350
# 27   27244    h        Barcelona          Osasuna          3  4.637070
# 28   27270    h        Barcelona           Girona          4  2.753330
# 29   27272    h        Barcelona       Real Betis          1  1.468440
# 30   27288    a          Leganes        Barcelona          0  0.598800
# 31   27292    h        Barcelona       Celta Vigo          4  2.565870
#
#     AwayGoals    AwayxG Result   Odds Win  Odds Draw  Odss Loss
# 0           2  3.488240      w  13.143847  12.955703  73.900040
# 1           1  1.099850      w  66.387872  17.954589  15.657534
# 2           2  1.518720      w   9.288890  25.010307  65.700803
# 3           0  0.422493      w  97.305892   2.093156   0.580999
# 4           4  2.593600      w  13.897616  16.556577  69.545796
# 5           5  4.193700      w  18.118114  12.610141  69.268351
# 6           0  0.929851      w  66.410359  19.002469  14.587170
# 7           2  0.751814      l  75.516296  15.361629   9.122068
# 8           3  2.493670      w   9.838240  15.705535  74.456218
# 9           1  0.599652      w  92.994445   5.011434   1.991592
# 10          4  2.515660      w  20.076581  18.233196  61.690215
# 11          1  0.787359      w  64.597451  21.011896  14.390653
# 12          0  0.514102      l  70.488895  20.252622   9.258482
# 13          2  1.937820      d  55.531273  17.797678  26.671025
# 14          2  0.599185      l  73.895460  17.347389   8.757150
# 15          5  5.380740      w   1.527167   3.075238  95.349559
# 16          2  1.541170      d  63.246839  17.050627  19.702509
# 17          1  0.772360      l  69.364208  18.624837  12.010954
# 18          2  0.710716      l  86.686391   8.886868   4.426464
# 19          1  3.503830      d   8.438495  11.008355  80.552718
# 20          1  1.303280      w  86.520171   7.691891   5.782740
# 21          0  0.126278      w  64.975373  31.126202   3.898425
# 22          4  1.931990      w  17.380739  21.605556  61.013704
# 23          0  1.309410      w  68.937113  15.840813  15.222041
# 24          2  1.664860      w   9.101821  22.834702  68.063477
# 25          0  0.000000      w  97.366131   2.633201   0.000000
# 26          4  2.162150      w  18.291964  20.007756  61.700279
# 27          0  0.533560      w  95.796792   3.122942   1.070078
# 28          1  0.490847      w  84.381797  11.242952   4.375227
# 29          1  0.249939      d  68.808629  25.147626   6.043745
# 30          1  1.101050      w  19.918718  32.454550  47.626732
# 31          3  2.504990      w  41.945196  18.211033  39.843755

# %%
# split data into home and away
home = df_cleaned[df_cleaned['side'] == 'h'].drop(columns = ['HomeTeam','side']).rename(columns={"AwayTeam":"Team","HomeGoals": "g", "AwayGoals": "gA","HomexG": "xG", "AwayxG": "xGa"})
home = home[["MatchID","Team","g","gA","xG","xGa","Odds Win","Odds Draw","Odss Loss","Result"]]
home

# %%
away = df_cleaned[df_cleaned['side'] == 'a'].drop(columns = ['AwayTeam','side']).rename(columns={"HomeTeam":"Team","HomeGoals": "gA", "AwayGoals": "g","HomexG": "xGa", "AwayxG": "xG"})
away = away[["MatchID","Team","g","gA","xG","xGa","Odds Win","Odds Draw","Odss Loss","Result"]]
away
